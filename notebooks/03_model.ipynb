# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
cv = CountVectorizer()

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\Notes\ML\Project\data\processed\preprocessed_data.csv", encoding = "latin-1") # Load the dataset from the specified path using pandas' read_csv function. The encoding parameter is set to "latin-1" to handle any special characters in the dataset.
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  go jurong point crazi avail bugi n great world...             111
# 1       0                              ok lar joke wif u oni              29
# 2       1  free entri 2 wkli comp win fa cup final tkt 21...             155
# 3       0                u dun say earli hor u c alreadi say              49
# 4       0               nah think goe usf live around though              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
X = cv.fit_transform(df['transformed_text']).toarray() # Transform the 'transformed_text' column of the DataFrame into a document-term matrix using the CountVectorizer. The fit_transform method is called to learn the vocabulary and transform the text data into a sparse matrix, which is then converted to a dense array using toarray().
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 X = cv.fit_transform(df['transformed_text']).toarray() # Transform the 'transformed_text' column of the DataFrame into a document-term matrix using the CountVectorizer. The fit_transform method is called to learn the vocabulary and transform the text data into a sparse matrix, which is then converted to a dense array using toarray().
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1386, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1378             warnings.warn(
#    1379                 "Upper case characters found in"
#    1380                 " vocabulary while 'lowercase'"
#    1381                 " is True. These entries will not"
#    1382                 " be matched with any documents"
#    1383             )
#    1384             break
# -> 1386 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1388 if self.binary:
#    1389     X.data.fill(1)
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:1273, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1271 for doc in raw_documents:
#    1272     feature_counter = {}
# -> 1273     for feature in analyze(doc):
#    1274         try:
#    1275             feature_idx = vocabulary[feature]
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:108, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#      86 """Chain together an optional series of text processing steps to go from
#      87 a single document to ngrams, with or without tokenizing or preprocessing.
#      88
#    (...)    104     A sequence of tokens, possibly with pairs, triples, etc.
#     105 """
#     107 if decoder is not None:
# --> 108     doc = decoder(doc)
#     109 if analyzer is not None:
#     110     doc = analyzer(doc)
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\sklearn\feature_extraction\text.py:241, in _VectorizerMixin.decode(self, doc)
#     238     doc = doc.decode(self.encoding, self.decode_error)
#     240 if doc is np.nan:
# --> 241     raise ValueError(
#     242         "np.nan is an invalid document, expected byte or unicode string."
#     243     )
#     245 return doc
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.
